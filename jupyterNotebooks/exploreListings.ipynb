# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine
import feather
# %matplotlib inline
sns.set_style("ticks")
sns.set_context("notebook", font_scale=1.1)

# %%
# mysql_cn= create_engine("mysql+pymysql://homestead:secret@192.168.10.10/etsy")
# listing = pd.read_sql_table('products', con=mysql_cn)

# %%
# listing.head()

# %%
# feather.write_dataframe(listing, '../_outputs/products.feather')

# %%
linsting = feather.read_dataframe('../_outputs/products.feather')
linsting
# Out:
#          listing_id   state    user_id               shop_id  page  \
# 0            444500  active      58746       HillcrestStudio     2
# 1           6361780  active     109071          chichiboulie     1
# 2           6361916  active     109071          chichiboulie     1
# 3           6877192  active     109071          chichiboulie     1
# 4           6880975  active      58746       HillcrestStudio     2
# 5           7877617  active     109071          chichiboulie     1
# 6          10541055  active    5306058            LUNATICART     4
# 7          11840630  active    5838985            lacollecte     2
# 8          13366101  active    5306058            LUNATICART     1
# 9          13838547  active    6089620  cathysavelspaintings     1
# 10         13838601  active    6089620  cathysavelspaintings     5
# 11         13850728  active    6089620  cathysavelspaintings     1
# 12         13850885  active    6089620  cathysavelspaintings     9
# ...

# %%
linsting.describe()
# Out:
#          listing_id       user_id          page   category_id      quantity  \
# count  1.139316e+06  1.139316e+06  1.139316e+06  1.139316e+06  1.139316e+06
# mean   4.979659e+08  7.276443e+07  1.122053e+01  6.906697e+07  2.758051e+01
# std    9.862446e+07  3.741653e+07  2.394596e+01  1.526345e+05  5.190835e+02
# min    4.445000e+05  1.373000e+04  1.000000e+00  0.000000e+00  1.000000e+00
# 25%    5.212572e+08  4.115670e+07  2.000000e+00  6.889201e+07  1.000000e+00
# 50%    5.336468e+08  7.385729e+07  4.000000e+00  6.915043e+07  1.000000e+00
# 75%    5.438776e+08  1.131641e+08  1.000000e+01  6.915150e+07  2.000000e+00
# max    5.608492e+08  1.233654e+08  3.160000e+02  6.920170e+07  2.250000e+04
#
#        shop_section_id         views  num_favorers
# count     1.139316e+06  1.139316e+06  1.139316e+06
# mean      1.456406e+07  7.970880e+01  1.094178e+01
# std       9.245972e+06  1.040692e+03  9.812734e+01
# min       0.000000e+00  0.000000e+00  0.000000e+00
# ...

# %%
linsting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1139316 entries, 0 to 1139315
# Data columns (total 30 columns):
# listing_id                1139316 non-null int64
# state                     1139316 non-null object
# user_id                   1139316 non-null int64
# shop_id                   1139316 non-null object
# page                      1139316 non-null int64
# category_id               1139316 non-null int64
# title                     1136318 non-null object
# description               1136301 non-null object
# creation_date             1139316 non-null datetime64[ns]
# ending_date               1139316 non-null datetime64[ns]
# original_creation_date    1139316 non-null datetime64[ns]
# last_modified_date        1139316 non-null datetime64[ns]
# price                     1139316 non-null object
# currency_code             1139316 non-null object
# quantity                  1139316 non-null int64
# tags                      1139316 non-null object
# ...
