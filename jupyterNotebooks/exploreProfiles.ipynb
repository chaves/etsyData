# %%
# %matplotlib inline
import glob
import json
import pandas as pd
import datetime
import re
from ftfy import fix_text

# %%
df = pd.DataFrame(columns = ['user_id', 'login_name', 'gender', 'join_date', 'bio', 'country_id', 'region', 'city', 
                             'is_seller', 'transaction_buy_count', 'transaction_sold_count',
                            'first_name', 'last_name'])
df
# Out:
# Empty DataFrame
# Columns: [user_id, login_name, gender, join_date, bio, country_id, region, city, is_seller, transaction_buy_count, transaction_sold_count, first_name, last_name]
# Index: []

# %%
def fix_text2(text):
    if type(text) is str:
        text = text.replace('\n',' ')
        text = text.replace('\r',' ')
        text = re.sub(' +',' ',text)
        return fix_text(text.rstrip())
    return None

# %%
def get_row(file):
    with open(file, 'r') as f:
        d = json.load(f)
        user_id = d['user_id']
        login_name = d['login_name']
        gender = d['gender']
        join_date = datetime.datetime.fromtimestamp(int(d['join_tsz'])).strftime('%Y-%m-%d')
        bio = fix_text2(d['bio'])
        country_id = d['country_id']
        region = fix_text2(d['region'])
        city = fix_text2(d['city'])
        is_seller = d['is_seller']
        transaction_buy_count = d['transaction_buy_count']
        transaction_sold_count = d['transaction_sold_count']
        first_name = fix_text2(d['first_name'])
        last_name = fix_text2(d['last_name'])
    
    return [user_id, login_name, gender, join_date, bio, country_id, region, city, 
            is_seller, transaction_buy_count, transaction_sold_count, first_name, last_name]

# %%
file_list = glob.glob("../_outputs/owners/*.json")
for file in file_list:
    df.loc[len(df)] = get_row(file)

# %%
df.head(10)
# Out:
#      user_id        login_name   gender   join_date  \
# 0   10000890        Nekojitaka   female  2010-05-14
# 1  100015026            lescra   female  2016-12-15
# 2  100019727        lenadreams  private  2016-10-26
# 3  100028373  jeanetjobrocante  private  2016-10-26
# 4  100029313          licie777   female  2016-10-26
# 5  100033171    florencebernal   female  2016-10-26
# 6  100056321       delphineajc  private  2016-10-26
# 7  100073924    hassibakessaci   female  2016-12-16
# 8  100086489   aurelienleshape     male  2016-10-27
# 9  100087641        daledenise   female  2016-10-27
#
#                                                  bio country_id region  \
# 0  Creative stuff, mostly handmade jewelry and ar...        103
# 1                                                          None
# 2                                                          None
# 3  I'm a Northern Irish Mum, going solo with my k...        103
# 4  Hello, ladies !! My name is Lucie Vidal, I liv...        103
# 5                                                           103
# 6                                                          None
# 7                                                          None
# 8                                                           103
# 9  I am English and am so lucky to have lived in ...        103
#
#               city is_seller transaction_buy_count transaction_sold_count  \
# 0        Montrouge      True                   352                     60
# 1                       True                     0                      0
# 2                       True                     0                     49
# 3          Limoges      True                     3                    110
# 4  Annecy-le-Vieux      True                     8                     18
# 5          Servian      True                     0                      5
# 6                       True                     1                      0
# 7                       True                     0                      0
# 8         Bordeaux      True                     0                      3
# 9            Eymet      True                     1                    539
#
#   first_name last_name
# 0       None      None
# 1    Evelyne     ORIOL
# 2       None      None
# 3         jo      None
# 4      Lucie     Vidal
# 5   FLORENCE    BERNAL
# 6       None      None
# 7    Hassiba   Kessaci
# 8   Aurélien     Duffo
# 9     denise      dale

# %%
df.describe()
# Out:
#          user_id      login_name  gender   join_date    bio  country_id  \
# count      14415           14415   14415       14415  14415       10544
# unique     14415           14415      82        2733   7386          24
# top     31392641  CaptainBretzel  female  2017-07-03                103
# freq           1               1    9699         500   7023       10489
#
#        region   city is_seller  transaction_buy_count  transaction_sold_count  \
# count   14415  14415     14415                  14415                   14415
# unique     56   3859         2                    431                     850
# top                       True                      0                       0
# freq    13784   3190     14414                   7860                    4266
#
#        first_name last_name
# count       12984      8343
# unique       6081      6983
# top
# freq          228       228

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14415 entries, 0 to 14414
# Data columns (total 13 columns):
# user_id                   14415 non-null object
# login_name                14415 non-null object
# gender                    14415 non-null object
# join_date                 14415 non-null object
# bio                       14415 non-null object
# country_id                10544 non-null object
# region                    14415 non-null object
# city                      14415 non-null object
# is_seller                 14415 non-null object
# transaction_buy_count     14415 non-null object
# transaction_sold_count    14415 non-null object
# first_name                12984 non-null object
# last_name                 8343 non-null object
# dtypes: object(13)
# memory usage: 1.5+ MB

# %%
# ExcelWriter pour ne pas convertir les liens
# https://stackoverflow.com/questions/35440528/how-to-save-in-xlsx-long-url-in-cell-using-pandas
# writer = pd.ExcelWriter(r'../_outputs/user_profiles.xlsx', engine='xlsxwriter', options={'strings_to_urls': False})
# df.to_excel(writer)
# writer.close()

# %%
df = pd.read_excel('../_outputs/user_profiles.xlsx')

# %%
female = df[df['gender'] == 'female']['user_id'].count()
female
# Out:
# 9699

# %%
male = df[df['gender'] == 'male']['user_id'].count()
male
# Out:
# 1234

# %%
ratio = female /(female + male)
ratio
# Out:
# 0.88713070520442694

# %%
df['transaction_buy_count'] = df['transaction_buy_count'].astype(int)
df['transaction_sold_count'] = df['transaction_sold_count'].astype(int)

# %%
df[df['gender'].isin(['female', 'male'])].groupby('gender')['transaction_buy_count', 'transaction_sold_count'].mean()
# Out:
#         transaction_buy_count  transaction_sold_count
# gender
# female              26.517373               98.414579
# male                 4.924635              105.902755

# %%
df.gender.unique()
# Out:
# array(['female', 'private', 'male', nan, 'family', 'Artiste', 'couple',
#        'furry', 'artiste', 'Marque', 'Couple', 'witch',
#        'Magicienne de liège', 'Studio', 'Magasin', 'Collectif créatif',
#        'groupe', 'marié', 'Both', 'Entreprise', 'Artisan', 'Famille',
#        'PRO', 'both', 'Boutique', 'Créateur', 'Lézard', 'Lak&#39;s Artes',
#        'créatrice', 'galerie d&#39;art', 'genderfluid', 'Team BUBU',
#        'SylHulaGirl', 'Alien', 'Viro', 'guru', 'Plasticien',
#        'ourse-papillon', 'Etre de lumière', 'Petite entreprise',
#        'GUILLOU Corinne', 'Agender', 'Poulpe',
#        'Petite créatrice de carnets et d&#39;accessoires', 'Créatrice',
#        'h/f', 'Princesse', 'socks', '3 femmes', 'Unisexe', 'Binôme',
#        'Synergie', 'Marque de mobilier design scandinave', 'Âme', 'Soeurs',
#        'Deux soeurs qui s&#39;adorent !', 'femme chat', 'man en vrouw',
#        'chat', 'Atelier de design', '1 homme et 1 femme', 'PROFESSIONNEL',
#        'Société', 'F&H', 'Renard', 'boutique', '🌵', 'Un couple',
#        'boutique rétro', '1000ola', 'on est deux !', 'Aurore',
#        'Une histoire de famille', 'Wolf', 'atelier', 'Human being',
#        'Couple d&#39;artistes', 'Gender Free', 'JeanLiane', 'Femmes',
#        'Night Owl', 'nintai art'], dtype=object)

# %%
# df.sort_values('count',ascending=False).groupby('city')['user_id'].count()
df[['city']].groupby(['city'])['city'] \
                             .count() \
                             .reset_index(name='count') \
                             .sort_values(['count'], ascending=False) \
                             .head(20)
# Out:
#                  city  count
# 2460            Paris   1605
# 1929             Lyon    377
# 3462         Toulouse    305
# 422          Bordeaux    249
# 2311           Nantes    219
# 1839            Lille    174
# 2024        Marseille    155
# 2218      Montpellier    151
# 2759           Rennes    125
# 2329             Nice    123
# 3370       Strasbourg    115
# 1296         Grenoble     72
# 37    Aix-en-Provence     71
# 2836            Rouen     61
# 1844          Limoges     56
# 90             Angers     53
# 2306            Nancy     53
# 218           Avignon     46
# 3471            Tours     46
# 1583      La Rochelle     46
